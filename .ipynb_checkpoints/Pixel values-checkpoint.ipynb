# %%
import torch
import numpy as np

# %%
import gzip
with open("/Users/gaky/Downloads/cifar-10-python.tar.gz", "rb") as f:
    file_content = f.read()
    f.close()
    data = np.frombuffer(gzip.decompress(file_content), dtype=np.uint8).reshape(-1, 32, 32)

# %%
data.shape
# Out:
# (181860, 32, 32)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data[0])

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
data = unpickle("/Users/gaky/Downloads/cifar-10-batches-py/data_batch_1")

# %%
data["data"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/45/wj5m3mk56b38wrkpv32mr0240000gn/T/ipykernel_35231/2449611345.py in <module>
# ----> 1 data["data"]
#
# KeyError: 'data'

# %%
import numpy as np
data = np.array(data[b'data'])

# %%
data = data.reshape(-1, 32, 32)

# %%
plt.imshow(data[5])

# %%
data = data.reshape(-1, 32, 32, 3)

# %%
data.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.imshow(data[5])
